# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_regression

#making matplot graphs interactive
# %matplotlib notebook

# %%
X,Y=make_regression(n_samples=1000,n_features=2,n_informative=2,noise=10,random_state=1)

X.shape,Y.shape
# Out:
# ((1000, 2), (1000,))

# %%
#n_informative => 1 => out of the 2 one feature is useless

plt.subplot(1,2,1)
plt.scatter(X[:,0],Y)


plt.subplot(1,2,2)
plt.scatter(X[:,1],Y)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure(figsize=(10,7))
ax=plt.axes(projection="3d")

ax.scatter3D(X[:,0],X[:,1],Y,color="green")
plt.title("3D Scatter Plot")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Here are two features:
'''
So, we need to find out the equation of the hyperplane=theta0+theta1*x1+theta2*x2

'''

# %% [markdown]
# # Implementing Linear Regressing using SK

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
alg=LR()

# %%
alg.fit(X,Y) #trainning the data
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
alg.coef_ #theta1 and theta2
# Out:
# array([16.62437639, 87.99042847])

# %%
alg.intercept_ #theta0
# Out:
# -0.2176641376001851

# %%
alg.predict([X[0],X[1]]) #y0 and y1 predictions
# Out:
# array([-186.58153868,  -90.66624357])

# %%
Y[0],Y[1] #actual values
# Out:
# (-198.36714169030483, -71.87770558832477)

# %%
Y_pred=alg.predict(X) #predciting values

# %%
alg.score(X,Y) #predicting score 

'''
Here X se Y_predict then commute score btw Y_pred and Y
'''
# Out:
# 0.988401838483157
