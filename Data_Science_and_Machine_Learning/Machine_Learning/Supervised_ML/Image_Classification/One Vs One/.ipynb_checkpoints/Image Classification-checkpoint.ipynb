# %% [markdown]
# ### Multiclass Classification Project
#
# Learning Goals
# - How to read different size images from a directory?
# - How to implement One-vs-one scheme for Multiclass classification?
# - How to use SVM for image classifcation?
# <img src="classes.png" alt="Classes" style="width: 700px;"/>

# %% [markdown]
# ## Dataset Preparation

# %%
import numpy as np
import os 
from pathlib import Path
import cv2

# %%
import matplotlib.pyplot as plt

# %%
p = Path("../images/")

dirs = p.glob("*")

labels_dict = {"cat":0,"dog":1,"horse":2,"human":3}

image_data = []
labels = []

for folder_dir in dirs:
    #print(folder_name)
    label = str(folder_dir).split("\\")[-1][:-1]
    
    
    for img_path in folder_dir.glob("*.jpg"):
        img_path=str(img_path).replace("\\","//")
        img=cv2.imread(img_path)
        rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        rgb_img=cv2.resize(rgb_img,(32,32))
        image_data.append(rgb_img)
        labels.append(labels_dict[label])

# %%
# Convert this into numpy array
image_data = np.array(image_data,dtype='float32')/255.0
labels = np.array(labels)

print(image_data.shape,labels.shape)
# Out:
# (808, 32, 32, 3) (808,)

# %% [markdown]
# ### Randomly Shuffle our Data!

# %%
import random

combined = list(zip(image_data,labels))
random.shuffle(combined)

#Unzip
image_data[:],labels[:] = zip(*combined)

# %% [markdown]
# ### Visualise this data!

# %%
from matplotlib import pyplot as plt

def drawImg(img):
    plt.imshow(img)
    plt.axis("off")
    plt.show()    
    return 

for i in range(10):
    drawImg(image_data[i])

# %% [markdown]
# ## SVM Classifier

# %%
class SVM:
    """SVM Class, Author : Prateek Narang"""
    def __init__(self,C=1.0):
        self.C = C
        self.W = 0
        self.b = 0
        
    def hingeLoss(self,W,b,X,Y):
        loss  = 0.0
        
        loss += .5*np.dot(W,W.T)
        
        m = X.shape[0]
        
        for i in range(m):
            ti = Y[i]*(np.dot(W,X[i].T)+b)
            loss += self.C *max(0,(1-ti))
            
        return loss[0][0]
    
    def fit(self,X,Y,batch_size=50,learning_rate=0.001,maxItr=500):
        
        no_of_features = X.shape[1]
        no_of_samples = X.shape[0]
        
        n = learning_rate
        c = self.C
        
        #Init the model parameters
        W = np.zeros((1,no_of_features))
        bias = 0
        
        #Initial Loss
        
        #Training from here...
        # Weight and Bias update rule that we discussed!
        losses = []
        
        for i in range(maxItr):
            #Training Loop
            
            l = self.hingeLoss(W,bias,X,Y)
            losses.append(l)
            ids = np.arange(no_of_samples)
            np.random.shuffle(ids)
            
            #Batch Gradient Descent(Paper) with random shuffling
            for batch_start in range(0,no_of_samples,batch_size):
                #Assume 0 gradient for the batch
                gradw = 0
                gradb = 0
                
                #Iterate over all examples in the mini batch
                for j in range(batch_start,batch_start+batch_size):
                    if j<no_of_samples:
                        i = ids[j]
                        ti =  Y[i]*(np.dot(W,X[i].T)+bias)
                        
                        if ti>1:
                            gradw += 0
                            gradb += 0
                        else:
                            gradw += c*Y[i]*X[i]
                            gradb += c*Y[i]
                            
                #Gradient for the batch is ready! Update W,B
                W = W - n*W + n*gradw
                bias = bias + n*gradb
                
        
        self.W = W
        self.b = bias
        return W,bias,losses

# %% [markdown]
# ## We need to convert data for One-for-One classifcation!

# %%
M = image_data.shape[0] 
image_data = image_data.reshape(M,-1)
print(image_data.shape)
print(labels.shape)
# Out:
# (808, 3072)
# (808,)

# %%
CLASSES = len(np.unique(labels))
print(CLASSES)
# Out:
# 4

# %%
def classWiseData(x,y):
    data = {}
    
    for i in range(CLASSES):
        data[i] = []
        
    for i in range(x.shape[0]):
        data[y[i]].append(x[i])
    
    for k in data.keys():
        data[k] = np.array(data[k])
        
    return data

# %%
data = classWiseData(image_data,labels)

# %%
data
# Out:
# {0: array([[0.49411765, 0.4627451 , 0.41960785, ..., 0.84705883, 0.70980394,
#          0.15294118],
#         [0.84705883, 0.8627451 , 0.85882354, ..., 0.8156863 , 0.84313726,
#          0.8901961 ],
#         [0.9764706 , 0.99215686, 0.99607843, ..., 0.84705883, 0.6156863 ,
#          0.3882353 ],
#         ...,
#         [0.45882353, 0.4745098 , 0.47843137, ..., 0.07843138, 0.08235294,
#          0.05490196],
#         [0.84705883, 0.8627451 , 0.85882354, ..., 0.8156863 , 0.84313726,
#          0.8901961 ],
#         [1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#          1.        ]], dtype=float32),
#  1: array([[0.92941177, 0.8745098 , 0.72156864, ..., 0.34901962, 0.24705882,
#          0.16470589],
#         [0.7921569 , 0.8745098 , 0.8862745 , ..., 0.4509804 , 0.47058824,
#          0.44705883],
#         [0.11372549, 0.11372549, 0.1254902 , ..., 0.16862746, 0.23137255,
#          0.25882354],
#         ...,
#         [0.05882353, 0.07450981, 0.01176471, ..., 0.5058824 , 0.5137255 ,
#          0.27058825],
#         [0.25882354, 0.2784314 , 0.1882353 , ..., 0.4745098 , 0.5058824 ,
#          0.30588236],
#         [0.30980393, 0.22352941, 0.12941177, ..., 0.9647059 , 0.91764706,
#          0.5764706 ]], dtype=float32),
#  2: array([[0.5058824 , 0.5921569 , 0.46666667, ..., 0.65882355, 0.63529414,
#          0.49803922],
#         [0.57254905, 0.58431375, 0.5568628 , ..., 0.37254903, 0.28627452,
#          0.14509805],
#         [0.3764706 , 0.43137255, 0.30588236, ..., 0.75686276, 0.654902  ,
#          0.5647059 ],
#         ...,
#         [0.08235294, 0.14117648, 0.01176471, ..., 0.57254905, 0.59607846,
#          0.23529412],
#         [0.4117647 , 0.46666667, 0.22745098, ..., 0.6509804 , 0.5882353 ,
#          0.5294118 ],
#         [0.81960785, 0.85490197, 0.88235295, ..., 0.5686275 , 0.6156863 ,
#          0.28627452]], dtype=float32),
#  3: array([[0.4509804 , 0.41960785, 0.36862746, ..., 0.6117647 , 0.5764706 ,
#          0.41568628],
#         [0.38431373, 0.38431373, 0.2627451 , ..., 0.6745098 , 0.69803923,
#          0.38431373],
#         [0.3254902 , 0.2627451 , 0.2       , ..., 0.3019608 , 0.28235295,
#          0.27058825],
#         ...,
#         [0.95686275, 0.93333334, 0.8862745 , ..., 0.3254902 , 0.43137255,
#          0.27058825],
#         [0.04313726, 0.03921569, 0.03137255, ..., 0.38431373, 0.36078432,
#          0.36078432],
#         [0.5372549 , 0.4       , 0.30980393, ..., 0.44705883, 0.2784314 ,
#          0.19215687]], dtype=float32)}

# %%
"""print(data[0].shape)
print(data[1].shape[0])
print(data[2].shape[0])
print(data[3].shape[0])
"""
# Out:
# 'print(data[0].shape)\nprint(data[1].shape[0])\nprint(data[2].shape[0])\nprint(data[3].shape[0])\n'

# %%
def getDataPairForSVM(d1,d2):
    """Combines Data of two classes into a signle matrix"""
    
    l1,l2 = d1.shape[0],d2.shape[0]
    
    samples = l1+l2
    features = d1.shape[1]
    
    data_pair = np.zeros((samples,features))
    data_labels = np.zeros((samples,))
    
    data_pair[:l1,:] = d1
    data_pair[l1:,:] = d2
    
    data_labels[:l1] = -1
    data_labels[l1:] = +1
    
    return data_pair,data_labels

# %% [markdown]
# ## Training  NC2 SVM's Part!

# %%
mySVM  = SVM()
xp, yp  = getDataPairForSVM(data[0],data[1])
w,b,loss  = mySVM.fit(xp,yp,learning_rate=0.00001,maxItr=1000)
#print(loss)
plt.plot(loss)

# %%
def trainSVMs(x,y):
    
    svm_classifiers = {}
    for i in range(CLASSES):
        svm_classifiers[i] = {}
        for j in range(i+1,CLASSES):
            xpair,ypair = getDataPairForSVM(data[i],data[j])
            wts,b,loss = mySVM.fit(xpair,ypair,learning_rate=0.00001,maxItr=1000)
            svm_classifiers[i][j] = (wts,b)
            
            plt.plot(loss)
            plt.show()
            
    
    return svm_classifiers

# %%
svm_classifiers = trainSVMs(image_data,labels)

# %%
svm_classifiers[0]
# Out:
# {1: (array([[ 0.02527347,  0.04113711,  0.04419766, ..., -0.0314769 ,
#           -0.03109089, -0.03509075]]),
#   0.10450000000000004),
#  2: (array([[-0.03458654, -0.02378123, -0.02083601, ..., -0.04112059,
#           -0.03143538, -0.05201645]]),
#   -0.02098999999999997),
#  3: (array([[ 0.00406001,  0.01188408,  0.01376735, ..., -0.01684033,
#           -0.0164277 , -0.01444107]]),
#   0.07748000000000028)}

# %%
#Parameters for Cats and dogs
cats_dogs = svm_classifiers[0][1]
cats_humans = svm_classifiers[0][3]
print(cats_dogs[0].shape)
print(cats_dogs[1])
# Out:
# (1, 3072)
# 0.10450000000000004

# %% [markdown]
# ## Prediction

# %%
def binaryPredict(x,w,b):
    z  = np.dot(x,w.T) + b
    if z>=0:
        return 1
    else:
        return -1

# %%
def predict(x):
    
    count = np.zeros((CLASSES,))
    
    for i in range(CLASSES):
        for j in range(i+1,CLASSES):
            w,b = svm_classifiers[i][j]
            #Take a majority prediction 
            z = binaryPredict(x,w,b)
            
            if(z==1):
                count[j] += 1
            else:
                count[i] += 1
    
    final_prediction = np.argmax(count)
    #print(count)
    return final_prediction

# %%
print(predict(image_data[0]))
print(labels[0])
# Out:
# 0
# 0

# %%
def accuracy(x,y):
    
    count = 0
    for i in range(x.shape[0]):
        prediction = predict(x[i])
        if(prediction==y[i]):
            count += 1
            
    return count/x.shape[0]

# %%
accuracy(image_data,labels)
# Out:
# 0.5977722772277227

# %% [markdown]
# ## Improving accuracy

# %%
#Alter the values of learning rate and max iterations to improve accuracy
mySVM  = SVM()
xp, yp  = getDataPairForSVM(data[0],data[1])
w,b,loss  = mySVM.fit(xp,yp,learning_rate=0.00001,maxItr=1000)
#print(loss)
plt.plot(loss)

# %% [markdown]
# # SVM using SK-learn

# %%
from sklearn import svm

# %%
svm_classifier = svm.SVC(kernel='linear',C=1.0)

# %%
svm_classifier.fit(image_data,labels)
svm_classifier.score(image_data,labels)
# Out:
# 0.6485148514851485
